# %% [markdown]
# Define constants

# %%
from os import getcwd, path
import matplotlib.pyplot as plt
import numpy as np

BASE_PATH = getcwd()

# GLOVE_UTILS = path.join(BASE_PATH, 'glove_utils.py')
DATA_UTILS = path.join(BASE_PATH, 'data_utils.py')
CONV_MODEL = path.join(BASE_PATH, 'convnet/train.py')

TRAIN_PATH = path.join(BASE_PATH, 'kc_data.json')

# %%
# exec(open(GLOVE_UTILS).read())
# print_top_similar('hello', count=10)
exec(open(DATA_UTILS).read())
exec(open(CONV_MODEL).read())
# Out:
# /Users/2359media/anaconda/envs/botbot-nlp/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# Use functions from the utils to extract and preprocess the training data

# %%
from keras.utils import to_categorical

X_data, y_data = get_data_pairs(data_from_json(TRAIN_PATH))

classes = list(set(y_data))
num_classes = len(classes)

X_train = X_data
y_train = np.array([
    to_categorical(classes.index(item), num_classes=num_classes)
    for item in y_data
], dtype='float32')

# %% [markdown]
# Plot the training data

# %%
cell_text = [
    [item, y_data[idx] + ' - ' + str(np.argmax(y_train[idx]))] 
    for (idx, item) in enumerate(X_train)
]
plt.table(cellText=cell_text[:20],
          colLabels=['Text', 'Intent'],
          loc='center') \
   .scale(1.8,1.8)
plt.axis('off')
plt.show()

# %%
print('Number of samples: %s, classes: %s' % (len(X_train), num_classes))
# Out:
# Number of samples: 10256, classes: 1427

# %%
train_model(X_train, y_train, classes=classes, non_static=False) # disables non-static channel for faster training
# Out:
# Importing /Users/2359media/Documents/botbot-nlp/data/glove/glove.6B.300d.pickle...
# Tokenizer contains 20989 unique tokens
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 512)          0
# __________________________________________________________________________________________________
# static_embeddings (Embedding)   (None, 512, 300)     6297000     input_1[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 512, 46)      0
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 510, 512)     461312      static_embeddings[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 509, 512)     614912      static_embeddings[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 508, 512)     768512      static_embeddings[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 510, 512)     71168       input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 509, 512)     94720       input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 508, 512)     118272      input_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 1, 512)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 1, 512)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 1, 512)       0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 1, 512)       0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 1, 512)       0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 1, 512)       0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 1, 1536)      0           max_pooling1d_1[0][0]
#                                                                  max_pooling1d_3[0][0]
#                                                                  max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 1, 1536)      0           max_pooling1d_2[0][0]
#                                                                  max_pooling1d_4[0][0]
#                                                                  max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1536)         0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1536)         0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1536)         0           flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1536)         0           flatten_2[0][0]
# __________________________________________________________________________________________________
# static_output (Dense)           (None, 256)          393472      dropout_1[0][0]
# __________________________________________________________________________________________________
# pos_output (Dense)              (None, 256)          393472      dropout_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 512)          0           static_output[0][0]
#                                                                  pos_output[0][0]
# __________________________________________________________________________________________________
# main_output (Dense)             (None, 1427)         732051      concatenate_3[0][0]
# ==================================================================================================
# Total params: 9,944,891
# Trainable params: 3,647,891
# Non-trainable params: 6,297,000
# __________________________________________________________________________________________________
# HBox(children=(IntProgress(value=0, description='Training', max=500), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='Epoch 0', max=10256), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='Epoch 1', max=10256), HTML(value='')))
# Epoch 00002: loss improved from inf to 4.50913, saving model to /Users/2359media/Documents/botbot-nlp/convnet/model/weights-02-4.5091.h5
# HBox(children=(IntProgress(value=0, description='Epoch 2', max=10256), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='Epoch 3', max=10256), HTML(value='')))
# Epoch 00004: loss improved from 4.50913 to 1.52531, saving model to /Users/2359media/Documents/botbot-nlp/convnet/model/weights-04-1.5253.h5
# HBox(children=(IntProgress(value=0, description='Epoch 4', max=10256), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='Epoch 5', max=10256), HTML(value='')))
# Epoch 00006: loss improved from 1.52531 to 0.82324, saving model to /Users/2359media/Documents/botbot-nlp/convnet/model/weights-06-0.8232.h5
# HBox(children=(IntProgress(value=0, description='Epoch 6', max=10256), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='Epoch 7', max=10256), HTML(value='')))
# Epoch 00008: loss improved from 0.82324 to 0.59125, saving model to /Users/2359media/Documents/botbot-nlp/convnet/model/weights-08-0.5913.h5
# HBox(children=(IntProgress(value=0, description='Epoch 8', max=10256), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='Epoch 9', max=10256), HTML(value='')))
# Epoch 00010: loss improved from 0.59125 to 0.49249, saving model to /Users/2359media/Documents/botbot-nlp/convnet/model/weights-10-0.4925.h5
# HBox(children=(IntProgress(value=0, description='Epoch 10', max=10256), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='Epoch 11', max=10256), HTML(value='')))
# Epoch 00012: loss improved from 0.49249 to 0.42988, saving model to /Users/2359media/Documents/botbot-nlp/convnet/model/weights-12-0.4299.h5
# HBox(children=(IntProgress(value=0, description='Epoch 12', max=10256), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='Epoch 13', max=10256), HTML(value='')))
# Epoch 00014: loss did not improve
# HBox(children=(IntProgress(value=0, description='Epoch 14', max=10256), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='Epoch 15', max=10256), HTML(value='')))
# Epoch 00016: loss improved from 0.42988 to 0.39355, saving model to /Users/2359media/Documents/botbot-nlp/convnet/model/weights-16-0.3935.h5
# HBox(children=(IntProgress(value=0, description='Epoch 16', max=10256), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='Epoch 17', max=10256), HTML(value='')))
# Epoch 00018: loss improved from 0.39355 to 0.36809, saving model to /Users/2359media/Documents/botbot-nlp/convnet/model/weights-18-0.3681.h5
# HBox(children=(IntProgress(value=0, description='Epoch 18', max=10256), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='Epoch 19', max=10256), HTML(value='')))
# Epoch 00020: loss did not improve
# HBox(children=(IntProgress(value=0, description='Epoch 20', max=10256), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='Epoch 21', max=10256), HTML(value='')))
# Epoch 00022: loss improved from 0.36809 to 0.35157, saving model to /Users/2359media/Documents/botbot-nlp/convnet/model/weights-22-0.3516.h5
# HBox(children=(IntProgress(value=0, description='Epoch 22', max=10256), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='Epoch 23', max=10256), HTML(value='')))
# Epoch 00024: loss improved from 0.35157 to 0.32621, saving model to /Users/2359media/Documents/botbot-nlp/convnet/model/weights-24-0.3262.h5
# HBox(children=(IntProgress(value=0, description='Epoch 24', max=10256), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='Epoch 25', max=10256), HTML(value='')))
# Epoch 00026: loss did not improve
# HBox(children=(IntProgress(value=0, description='Epoch 26', max=10256), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='Epoch 27', max=10256), HTML(value='')))
# Epoch 00028: loss improved from 0.32621 to 0.31967, saving model to /Users/2359media/Documents/botbot-nlp/convnet/model/weights-28-0.3197.h5
# HBox(children=(IntProgress(value=0, description='Epoch 28', max=10256), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='Epoch 29', max=10256), HTML(value='')))
