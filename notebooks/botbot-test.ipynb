# %%
from os import getcwd, path
import sys
import matplotlib.pyplot as plt
import numpy as np

BASE_PATH = getcwd()
sys.path.append(BASE_PATH)

from text_classification.fast_text.train import trainIters

# %%
BOTBOT_TEST_PATH = path.join(BASE_PATH, 'data/botbot/francis.json')

# %%
import json
BOTBOT_DATA = json.load(open(BOTBOT_TEST_PATH, 'r'))
print('Loaded %s intents' % len(BOTBOT_DATA))
# Out:
# Loaded 323 intents

# %%
IGNORE_CONTEXT = True # flag for ignoring intents with contexts

classes = list(set([
    intent['name'] 
    for intent in BOTBOT_DATA 
    if (not IGNORE_CONTEXT or len(intent['inContexts']) == 0)
]))

training_data = []

for intent in BOTBOT_DATA:
    examples = intent['examples']
    if intent['name'] in classes:
        cls = classes.index(intent['name'])
        if len(examples) > 0:
            for example in examples:
                text = ''.join([entity['text'] for entity in example['entities']])
                training_data.append((text, cls))

print('Loaded %s examples' % len(training_data))
# Out:
# Loaded 5215 examples

# %%
losses, model = trainIters(training_data, 
                           classes, 
                           n_iters=50, 
                           log_every=5, 
                           verbose=1,
                           learning_rate=1e-3, 
                           batch_size=64)

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

plt.figure()
fig, ax = plt.subplots()
loc = ticker.MultipleLocator(base=5)
ax.yaxis.set_major_locator(loc)
plt.plot(losses)
# Out:
# Training started
# Importing /Users/2359media/Documents/botbot-nlp/data/glove/glove.840B.300d.txt...
# 0m 43s (- 6m 32s) (5 10%) 0.0734 - accuracy: 0.1195
# 1m 22s (- 5m 29s) (10 20%) 0.0367 - accuracy: 0.4875
# 1m 56s (- 4m 32s) (15 30%) 0.0176 - accuracy: 0.7180
# 2m 31s (- 3m 46s) (20 40%) 0.0058 - accuracy: 0.8905
# 3m 4s (- 3m 4s) (25 50%) 0.0028 - accuracy: 0.9466
# 3m 52s (- 2m 34s) (30 60%) 0.0016 - accuracy: 0.9671
# 4m 28s (- 1m 54s) (35 70%) 0.0013 - accuracy: 0.9750
# 5m 5s (- 1m 16s) (40 80%) 0.0023 - accuracy: 0.9720
# 5m 37s (- 0m 37s) (45 90%) 0.0023 - accuracy: 0.9677
# 6m 10s (- 0m 0s) (50 100%) 0.0022 - accuracy: 0.9722

# %%
from text_classification.fast_text.train import evaluate_all
print('Model recall: %s' % evaluate_all(model, training_data))
# Out:
# Model recall: 0.8713326941514861

# %%
from common.utils import argmax
from text_classification.fast_text.model import process_sentences

print('Model errors:')
for sentence, gt_class in training_data: 
    precheck_sent = process_sentences([sentence])
    pred_class = argmax(model(*precheck_sent))
    if gt_class != pred_class:
        print('Sentence: %s' % sentence)
        print('Ground truth: %s, Predicted: %s\r\n' % (classes[gt_class], classes[pred_class]))
# Out:
# Model errors:
# Sentence: fibre entertainment bundle
# Ground truth: CIS - FibreEntertainment Bundle, Predicted: CIS-Mobile-Product-FibreBroadbandPlans
#
# Sentence: what is FEB+
# Ground truth: CIS - FibreEntertainment Bundle, Predicted: CIS-Mobile-Product-FibreBroadbandPlans
#
# Sentence: what is feb
# Ground truth: CIS - FibreEntertainment Bundle, Predicted: CIS-Others-FEB
#
# Sentence: are you able to check on my eligibility for one of my handphone line
# Ground truth: CIS-1688, Predicted: CIS-MobilePlan-ContractStatus
#
# Sentence: how can i opt out of my caller ID
# Ground truth: CIS-1688, Predicted: CIS-Online-DeliveryOptions
#
# Sentence: i lost my phone
# Ground truth: CIS-1688, Predicted: CIS-Mobile-AddOn-ZoneAlarm
#
# Sentence: what phone number to send my complaints
# Ground truth: CIS-1688, Predicted: CIS-Mobile-AddOn-CallerNumberNonDisplay
#
# Sentence: is there any phone number i can call to express my complaints
# Ground truth: CIS-1688, Predicted: CIS-HotlineNumber-Service
#
# Sentence: where should i call if i want to complain
# Ground truth: CIS-1688, Predicted: CIS-HotlineNumber-Service
#
# Sentence: what number should i call if i want to complain
# Ground truth: CIS-1688, Predicted: CIS-HotlineNumber-Service
#
# Sentence: how to replace SIMcard
# Ground truth: CIS-1688, Predicted: CIS-Mobile-AddOn-MobileSwop
#
# Sentence: i have to replace my simcard
# Ground truth: CIS-1688, Predicted: CIS-Online-Authorisation
#
# Sentence: why is the connection very bad here
# Ground truth: CIS-1688, Predicted: smalltalk.appraisal.bad
#
# Sentence: terrible network in here
# Ground truth: CIS-1688, Predicted: CIS-Promo-Latest
#
# Sentence: i dont want my caller ID
# Ground truth: CIS-1688, Predicted: CIS-HotlineNumber-Service
#
# Sentence: i am experiencing some issues with my network
# Ground truth: CIS-1688, Predicted: CIS-MobilePlan-Port-in
#
# Sentence: my internet connection broke
# Ground truth: CIS-1688, Predicted: CIS-Mobile-AddOn-ZoneAlarm
#
# Sentence: my phone was just stolen
# Ground truth: CIS-1688, Predicted: CIS-Mobile-AddOn-ZoneAlarm
#
# Sentence: network is down
# Ground truth: CIS-1688, Predicted: smalltalk.agent.origin
#
# Sentence: the connection was very bad
# Ground truth: CIS-1688, Predicted: smalltalk.appraisal.bad
#
# Sentence: cancel caller ID
# Ground truth: CIS-1688, Predicted: CIS-Mobile-AddOn-CallerAlert
#
# Sentence: cancel caller
# Ground truth: CIS-1688, Predicted: CIS-Mobile-AddOn-CallerAlert
#
# Sentence: how to opt out caller ID
# Ground truth: CIS-1688, Predicted: CIS-Mobile-AddOn-CallerAlert
#
# Sentence: i think the network is unstable
# Ground truth: CIS-1688, Predicted: CIS-MobilePlan-Port-in
#
# Sentence: lost my phone how to report
# Ground truth: CIS-1688, Predicted: CIS-Mobile-AddOn-ZoneAlarm
#
# Sentence: Call 1688
# Ground truth: CIS-1688, Predicted: CIS-HotlineNumber-Service
#
# Sentence: is singtel cis cheaper than starhub
# Ground truth: CIS-About-BetterBenefits, Predicted: SmallTalk-Competitors
#
# Sentence: mobile phone under cis or not
# Ground truth: CIS-About-CompanyEnrollment, Predicted: CIS-MobilePlan-CheckifUnderCIS
#
# Sentence: how should i know that my phone's's under cis
# Ground truth: CIS-About-CompanyEnrollment, Predicted: CIS-MobilePlan-CheckifUnderCIS
#
# Sentence: i want to know whether my line's been controlled by cis
# Ground truth: CIS-About-CompanyEnrollment, Predicted: CIS-MobilePlan-CheckifUnderCIS
#
# Sentence: check my mobile plan whether it's under cis
# Ground truth: CIS-About-CompanyEnrollment, Predicted: CIS-MobilePlan-CheckifUnderCIS
#
# Sentence: i want to check if my line is already under cis
# Ground truth: CIS-About-CompanyEnrollment, Predicted: CIS-MobilePlan-CheckifUnderCIS
#
# Sentence: how do i know if my phone is under cis
# Ground truth: CIS-About-CompanyEnrollment, Predicted: CIS-MobilePlan-CheckifUnderCIS
#
# Sentence: my company has less than 200 employees
# Ground truth: CIS-About-EnrolCriteria-Complaints, Predicted: CIS-About-CompanyEnrollment#Less200
#
# Sentence: i want to check eligibility
# Ground truth: CIS-About-EnrolCriteria, Predicted: CIS-MobilePlan-ContractStatus
#
# Sentence: how to check if we are eligible
# Ground truth: CIS-About-EnrolCriteria, Predicted: CIS-About-CompanyEnrollment#Less200
#
# Sentence: i want to enrol my company to cis
# Ground truth: CIS-About-EnrolCriteria, Predicted: CIS-About-Subsidiary
#
# Sentence: i want to enroll my company into cis
# Ground truth: CIS-About-EnrolCriteria, Predicted: CIS-About-Subsidiary
#
# Sentence: company wants to join cis
# Ground truth: CIS-About-EnrolCriteria, Predicted: CIS-About-Subsidiary
#
# Sentence: how can i sign my company up
# Ground truth: CIS-About-EnrolCriteria, Predicted: CIS-About-Subsidiary
#
# Sentence: am i eligible
# Ground truth: CIS-About-EnrolCriteria, Predicted: CIS-MobilePlan-ContractStatus
#
# Sentence: who is eligible
# Ground truth: CIS-About-EnrolCriteria, Predicted: CIS-Others-Eligible
#
# Sentence: how can i get my company to join cis
# Ground truth: CIS-About-EnrolCriteria, Predicted: CIS-About-Subsidiary
#
# Sentence: why i cannot sign up for cis
# Ground truth: CIS-About-EnrolCriteria, Predicted: CIS-HotlineNumber-Service
#
# Sentence: why am i not eligible for cis
# Ground truth: CIS-About-EnrolCriteria, Predicted: CIS-Others-Eligible
#
# Sentence: cis fulfillment
# Ground truth: CIS-About-EnrolCriteria, Predicted: CIS-MobilePlan-CheckifUnderCIS
#
# Sentence: what is cis
# Ground truth: CIS-About-MenuWhatIsBenefits, Predicted: CIS-HotlineNumber-Service
#
# Sentence: is cis any good
# Ground truth: CIS-About-WhatIsandBenefits, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: what asset does cis have
# Ground truth: CIS-About-WhatIsandBenefits, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: why is cis better than any other company
# Ground truth: CIS-About-WhatIsandBenefits, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: advantage of cis
# Ground truth: CIS-About-WhatIsandBenefits, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: why should we consider you to be our partner
# Ground truth: CIS-About-WhatIsandBenefits, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: why is cis good
# Ground truth: CIS-About-WhatIsandBenefits, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: what's so good about cis
# Ground truth: CIS-About-WhatIsandBenefits, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: what's great about cis
# Ground truth: CIS-About-WhatIsandBenefits, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: what is CIS
# Ground truth: CIS-About-WhatIsandBenefits, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: what are the benefits of enrolling in CIS
# Ground truth: CIS-About-WhatIsandBenefits, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: what good can cis bring if i join my company
# Ground truth: CIS-About-WhatIsandBenefits, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: how good is it when my company joins cis
# Ground truth: CIS-About-WhatIsandBenefits, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: what good can my company get if joining cis
# Ground truth: CIS-About-WhatIsandBenefits, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: why should we enrol in CIS
# Ground truth: CIS-About-WhatIsandBenefits, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: what are the benefits of joining CIS
# Ground truth: CIS-About-WhatIsandBenefits, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: explain CIS
# Ground truth: CIS-About-WhatIsandBenefits, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: can you explain what is CIS
# Ground truth: CIS-About-WhatIsandBenefits, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: why should my company join CIS
# Ground truth: CIS-About-WhatIsandBenefits, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: what are the benefits of CIS
# Ground truth: CIS-About-WhatIsandBenefits, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: what are the benefits of enrolling my company to CIS
# Ground truth: CIS-About-WhatIsandBenefits, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: what perks do i get for CIS
# Ground truth: CIS-About-WhatIsandBenefits, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: why should i join CIS
# Ground truth: CIS-About-WhatIsandBenefits, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: tell me more about the scheme
# Ground truth: CIS-About-WhatIsandBenefits, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: what is corporate individual scheme
# Ground truth: CIS-About-WhatIsandBenefits, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: can u understand me
# Ground truth: CIS-Apology, Predicted: smalltalk.agent.sex
#
# Sentence: weak
# Ground truth: CIS-Apology, Predicted: smalltalk.appraisal.bad
#
# Sentence: shit
# Ground truth: CIS-Apology, Predicted: smalltalk.vulgarities
#
# Sentence: lousy
# Ground truth: CIS-Apology, Predicted: smalltalk.appraisal.bad
#
# Sentence: cb la this francis very rude
# Ground truth: CIS-Apology, Predicted: smalltalk.vulgarities
#
# Sentence: why is cis so stupid
# Ground truth: CIS-Apology, Predicted: smalltalk.vulgarities
#
# Sentence: you are not answering my question
# Ground truth: CIS-Apology, Predicted: smalltalk.dialog.wrong
#
# Sentence: Phone price
# Ground truth: CIS-Devices-Menu, Predicted: CIS-Mobile-AddOn-SamsungConcierge
#
# Sentence: can i see the menu for devices again
# Ground truth: CIS-Devices-Menu, Predicted: CIS-Menu
# Sentence: when can i purchase the samsung note 8
# Ground truth: CIS-Devices-Note8, Predicted: CIS-Devices-LatestIphone
#
# Sentence: i want to buy the samsung note 8
# Ground truth: CIS-Devices-Note8, Predicted: CIS-Devices-LatestIphone
#
# Sentence: when can i purchase the note 8
# Ground truth: CIS-Devices-Note8, Predicted: CIS-Devices-LatestIphone
#
# Sentence: can i purchase the note 8
# Ground truth: CIS-Devices-Note8, Predicted: CIS-Devices-LatestIphone
#
# Sentence: how much is the xiaomi
# Ground truth: CIS-Devices, Predicted: CIS-MobilePlan-Discount
#
# Sentence: how much is the ino price
# Ground truth: CIS-Devices, Predicted: CIS-MobilePlan-Discount
#
# Sentence: i want a free phone
# Ground truth: CIS-Devices, Predicted: CIS-MobilePlan-NoMobilePhone
#
# Sentence: i need a free phone
# Ground truth: CIS-Devices, Predicted: CIS-MobilePlan-NoMobilePhone
#
# Sentence: what is the best phone now
# Ground truth: CIS-Devices, Predicted: CIS-Mobile-AddOn-ZoneAlarm
#
# Sentence: what is the cheapest phone
# Ground truth: CIS-Devices, Predicted: CIS-Mobile-AddOn-WifiCalling
#
# Sentence: what is the phone price
# Ground truth: CIS-Devices, Predicted: CIS-Mobile-AddOn-ZoneAlarm
#
# Sentence: what is iphone discount
# Ground truth: CIS-Devices, Predicted: CIS-Mobile-Product-SingtelTV
#
# Sentence: how much is the iphone for recontract
# Ground truth: CIS-Devices, Predicted: CIS-MobilePlan-Recontract
#
# Sentence: Is there stock for the new iPhone
# Ground truth: CIS-Devices, Predicted: CIS-Devices-LatestIphone
#
# Sentence: i want to buy the most recent handsets
# Ground truth: CIS-Devices, Predicted: CIS-Mobile-Product-EnterpriseMobileBundle
#
# Sentence: how much is LG
# Ground truth: CIS-Devices, Predicted: CIS-Mobile-AddOn-CAST-Fox+
#
# Sentence: how much is motorola
# Ground truth: CIS-Devices, Predicted: CIS-Mobile-AddOn-CAST-Fox+
#
# Sentence: how much is microsoft
# Ground truth: CIS-Devices, Predicted: CIS-Mobile-AddOn-CAST-ViuPremium
#
# Sentence: are there still any handsets available
# Ground truth: CIS-Devices, Predicted: smalltalk.agent.there
#
# Sentence: what phone can i buy
# Ground truth: CIS-Devices, Predicted: CIS-MobilePlan-NoMobilePhone
#
# Sentence: is there stock for iphone
# Ground truth: CIS-Devices, Predicted: CIS-Devices-LatestIphone
#
# Sentence: what is the availability of your handsets
# Ground truth: CIS-Devices, Predicted: CIS-Mobile-AddOn-WifiCalling
#
# Sentence: wassup
# Ground truth: CIS-Greetings, Predicted: smalltalk.greetings.whatsup
#
# Sentence: hey guys
# Ground truth: CIS-Greetings, Predicted: smalltalk.emotions.ha_ha
#
# Sentence: Hello
# Ground truth: CIS-Greetings, Predicted: smalltalk.dialog.hug
#
# Sentence: HELLOO
# Ground truth: CIS-Greetings, Predicted: SmallTalk-Weather
#
# Sentence: Start
# Ground truth: CIS-Greetings, Predicted: CIS-Menu
#
# Sentence: what can u do
# Ground truth: CIS-Greetings, Predicted: CIS-Menu
#
# Sentence: What is your name
# Ground truth: CIS-Greetings, Predicted: smalltalk.gender
#
# Sentence: hello
# Ground truth: CIS-Greetings, Predicted: smalltalk.dialog.hug
#
# Sentence: hiiiiiiiiiiiiiiiiii
# Ground truth: CIS-Greetings, Predicted: CIS-HotlineNumber-Service
#
# Sentence: what is your name
# Ground truth: CIS-Greetings, Predicted: smalltalk.gender
#
# Sentence: get started
# Ground truth: CIS-Greetings, Predicted: smalltalk.greetings.bye
#
# Sentence: how are you doing
# Ground truth: CIS-Greetings, Predicted: smalltalk.greetings.how_are_you
#
# Sentence: greetings!
# Ground truth: CIS-Greetings, Predicted: CIS-Mobile-Product-SingtelOnlineGifts
#
# Sentence: heyho
# Ground truth: CIS-Greetings, Predicted: smalltalk.greetings.whatsup
#
# Sentence: hey bot
# Ground truth: CIS-Greetings, Predicted: smalltalk.agent.chatbot
#
# Sentence: evening
# Ground truth: CIS-Greetings, Predicted: smalltalk.greetings.goodevening
#
# Sentence: morning
# Ground truth: CIS-Greetings, Predicted: smalltalk.greetings.goodmorning
#
# Sentence: good afternoon
# Ground truth: CIS-Greetings, Predicted: smalltalk.user.good
#
# Sentence: good evening
# Ground truth: CIS-Greetings, Predicted: smalltalk.greetings.goodevening
#
# Sentence: good morning
# Ground truth: CIS-Greetings, Predicted: smalltalk.greetings.goodmorning
#
# Sentence: can we start
# Ground truth: CIS-Greetings, Predicted: CIS-About-CompanyEnrollment#Less200
#
# Sentence: hey
# Ground truth: CIS-Greetings, Predicted: smalltalk.emotions.ha_ha
#
# Sentence: what are you
# Ground truth: CIS-Greetings, Predicted: smalltalk.agent.acquaintance
#
# Sentence: what is this
# Ground truth: CIS-Greetings, Predicted: smalltalk.greetings.whatsup
#
# Sentence: who are you
# Ground truth: CIS-Greetings, Predicted: smalltalk.agent.acquaintance
#
# Sentence: what's up
# Ground truth: CIS-Greetings, Predicted: smalltalk.greetings.whatsup
#
# Sentence: hihi
# Ground truth: CIS-Greetings, Predicted: CIS-FEB-InstallmentCost
#
# Sentence: yo
# Ground truth: CIS-Greetings, Predicted: smalltalk.emotions.ha_ha
#
# Sentence: can you help me
# Ground truth: CIS-Menu, Predicted: smalltalk.agent.can_you_help
#
# Sentence: i need some help here
# Ground truth: CIS-Menu, Predicted: smalltalk.agent.can_you_help
#
# Sentence: help
# Ground truth: CIS-Menu, Predicted: smalltalk.agent.can_you_help
#
# Sentence: how much is cast
# Ground truth: CIS-Mobile-AddOn-CAST, Predicted: CIS-Mobile-AddOn-CAST-ViuPremium
#
# Sentence: how can i sign up for datax2
# Ground truth: CIS-Mobile-AddOn-DataX2, Predicted: CIS-Mobile-AddOn-CAST-ViuPremium
#
# Sentence: how can i sign up for data x2
# Ground truth: CIS-Mobile-AddOn-DataX2, Predicted: CIS-Mobile-AddOn-Data
#
# Sentence: how do i go about subscribing to datax2
# Ground truth: CIS-Mobile-AddOn-DataX2, Predicted: CIS-Mobile-Product-EnterpriseMobileBundle
#
# Sentence: how much does datax2 cost
# Ground truth: CIS-Mobile-AddOn-DataX2, Predicted: CIS-Mobile-AddOn-CAST-ViuPremium
#
# Sentence: how much is datax2
# Ground truth: CIS-Mobile-AddOn-DataX2, Predicted: CIS-Mobile-AddOn-CAST-ViuPremium
#
# Sentence: double my data
# Ground truth: CIS-Mobile-AddOn-DataX2, Predicted: CIS-Mobile-AddOn-Data
#
# Sentence: how do i increase my data by 2
# Ground truth: CIS-Mobile-AddOn-DataX2, Predicted: CIS-Mobile-AddOn-Data
#
# Sentence: how can i subscribe to datax2
# Ground truth: CIS-Mobile-AddOn-DataX2, Predicted: CIS-Mobile-AddOn-CAST-ViuPremium
#
# Sentence: how can i sign up for data x3
# Ground truth: CIS-Mobile-AddOn-DataX3, Predicted: CIS-Mobile-AddOn-Data
#
# Sentence: how can i sign up for datax3
# Ground truth: CIS-Mobile-AddOn-DataX3, Predicted: CIS-Mobile-AddOn-CAST-ViuPremium
#
# Sentence: how do i triple my data
# Ground truth: CIS-Mobile-AddOn-DataX3, Predicted: CIS-Mobile-AddOn-Data
#
# Sentence: i want to subscribe to datax3
# Ground truth: CIS-Mobile-AddOn-DataX3, Predicted: CIS-MobilePlan-Recontract
#
# Sentence: what can i get for 10 dollars
# Ground truth: CIS-Mobile-AddOn-DataX3, Predicted: CIS-Promo-Menu
#
# Sentence: i want the most data
# Ground truth: CIS-Mobile-AddOn-DataX3, Predicted: CIS-Mobile-AddOn-Data
#
# Sentence: what is datax3
# Ground truth: CIS-Mobile-AddOn-DataX3, Predicted: smalltalk.greetings.whatsup
#
# Sentence: i wish to sign up to mobileshare
# Ground truth: CIS-Mobile-AddOn-MobileShare, Predicted: CIS-MobilePlan-TransferOwnership
#
# Sentence: how do i find out more about mobileshare
# Ground truth: CIS-Mobile-AddOn-MobileShare, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: What is mobileshare
# Ground truth: CIS-Mobile-AddOn-MobileShare, Predicted: smalltalk.greetings.whatsup
#
# Sentence: can i share my phone plan
# Ground truth: CIS-Mobile-AddOn-MobileShare, Predicted: CIS-Mobile-AddOn-ZoneAlarm
#
# Sentence: how much is mobileshare
# Ground truth: CIS-Mobile-AddOn-MobileShare, Predicted: CIS-Mobile-AddOn-CAST-AsianPlus
#
# Sentence: i want to share
# Ground truth: CIS-Mobile-AddOn-MobileShare, Predicted: CIS-Mobile-AddOn-SMSMore
#
# Sentence: how to share talk time
# Ground truth: CIS-Mobile-AddOn-MobileShare, Predicted: CIS-Mobile-AddOn-TalkMoreExtra
#
# Sentence: port over
# Ground truth: CIS-Mobile-PortIn-WhatIs, Predicted: CIS-MobilePlan-Port-in
#
# Sentence: port-in meaning
# Ground truth: CIS-Mobile-PortIn-WhatIs, Predicted: CIS-MobilePlan-Port-in
#
# Sentence: what is mobile broadband
# Ground truth: CIS-Mobile-Product-BroadbandPlans, Predicted: CIS-Mobile-Product-FibreBroadbandPlans
#
# Sentence: i want to sign up for broadband
# Ground truth: CIS-Mobile-Product-BroadbandPlans, Predicted: CIS-Mobile-Product-FibreBroadbandPlans
#
# Sentence: MBP
# Ground truth: CIS-Mobile-Product-BroadbandPlans, Predicted: CIS-Mobile-AddOn-SamsungConcierge
#
# Sentence: how many different broadband plans are there
# Ground truth: CIS-Mobile-Product-BroadbandPlans, Predicted: CIS-Mobile-Product-FibreBroadbandPlans
#
# Sentence: how can i sign up for mobile broadband plans
# Ground truth: CIS-Mobile-Product-BroadbandPlans, Predicted: CIS-Mobile-Product-EnterpriseMobileBundle
#
# Sentence: combo mobile plan 10
# Ground truth: CIS-Mobile-Product-BroadbandPlans, Predicted: CIS-MobilePlan-NewPlan
#
# Sentence: combo mobile plan 5
# Ground truth: CIS-Mobile-Product-BroadbandPlans, Predicted: CIS-MobilePlan-NewPlan
#
# Sentence: combo mobile plan 2
# Ground truth: CIS-Mobile-Product-BroadbandPlans, Predicted: CIS-MobilePlan-NewPlan
#
# Sentence: i want to change my ringtone
# Ground truth: CIS-Mobile-Product-Connecting Tones, Predicted: CIS-MobilePlan-RecontractDeviceUpgradeCharges
#
# Sentence: i want to know about CMES
# Ground truth: CIS-Mobile-Product-CorporateExecutiveScheme-WhatISCMES, Predicted: smalltalk.agent.acquaintance
# Sentence: i want to call $countries
# Ground truth: CIS-Mobile-Product-IDDCalls, Predicted: CIS-HotlineNumber-Service
#
# Sentence: cheap international phone calls
# Ground truth: CIS-Mobile-Product-IDDCalls, Predicted: CIS-Mobile-AddOn-V019
#
# Sentence: how can i make international phone calls
# Ground truth: CIS-Mobile-Product-IDDCalls, Predicted: CIS-Mobile-AddOn-V019
#
# Sentence: i want info on readyroam
# Ground truth: CIS-Mobile-Product-ReadyRoam, Predicted: CIS-Mobile-AddOn-Roaming
#
# Sentence: What are the charges for e
# Ground truth: CIS-Mobile-Product-ReadyRoam, Predicted: CIS-MobilePlan-RecontractAdminCharges
#
# Sentence: ready to go roaming
# Ground truth: CIS-Mobile-Product-ReadyRoam, Predicted: CIS-Mobile-AddOn-Roaming
#
# Sentence: i want to sign up for ready roam
# Ground truth: CIS-Mobile-Product-ReadyRoam, Predicted: CIS-Mobile-AddOn-Roaming
#
# Sentence: overseas roaming for 30 days
# Ground truth: CIS-Mobile-Product-ReadyRoam, Predicted: CIS-Mobile-AddOn-Roaming
#
# Sentence: what exactly is ready roam and how do i go about signing up for it
# Ground truth: CIS-Mobile-Product-ReadyRoam, Predicted: smalltalk.agent.can_you_help
#
# Sentence: how do i find out more about readyroam
# Ground truth: CIS-Mobile-Product-ReadyRoam, Predicted: CIS-Mobile-AddOn-CAST
#
# Sentence: i want to buy readyroam
# Ground truth: CIS-Mobile-Product-ReadyRoam, Predicted: CIS-Mobile-AddOn-CAST-SportsPlus
#
# Sentence: i want to buy ready roam
# Ground truth: CIS-Mobile-Product-ReadyRoam, Predicted: CIS-Mobile-AddOn-Roaming
#
# Sentence: how can i sign up for ready roam
# Ground truth: CIS-Mobile-Product-ReadyRoam, Predicted: CIS-Mobile-Product-EnterpriseMobileBundle
#
# Sentence: how to get readyroam
# Ground truth: CIS-Mobile-Product-ReadyRoam, Predicted: CIS-Mobile-AddOn-Roaming
#
# Sentence: i want more info on readyroam
# Ground truth: CIS-Mobile-Product-ReadyRoam, Predicted: CIS-Mobile-AddOn-Roaming
#
# Sentence: does singtel provide any roaming data service
# Ground truth: CIS-Mobile-Product-RoamingOverseasData, Predicted: CIS-Mobile-AddOn-Roaming
#
# Sentence: i'm going abroad soon. how do i get the roaming service there
# Ground truth: CIS-Mobile-Product-RoamingOverseasData, Predicted: CIS-Mobile-AddOn-Roaming
#
# Sentence: how can i get the roaming service abroad
# Ground truth: CIS-Mobile-Product-RoamingOverseasData, Predicted: CIS-Mobile-AddOn-Roaming
#
# Sentence: i want to apply for roaming data service
# Ground truth: CIS-Mobile-Product-RoamingOverseasData, Predicted: CIS-Mobile-AddOn-Roaming
#
# Sentence: how to do a mobile roaming plan
# Ground truth: CIS-Mobile-Product-RoamingOverseasData, Predicted: CIS-Mobile-AddOn-Roaming
#
# Sentence: i want to sign up for roaming data service
# Ground truth: CIS-Mobile-Product-RoamingOverseasData, Predicted: CIS-Mobile-AddOn-Roaming
#
# Sentence: how to apply for roaming data service
# Ground truth: CIS-Mobile-Product-RoamingOverseasData, Predicted: CIS-Mobile-AddOn-Roaming
#
# Sentence: how to enroll roaming data service
# Ground truth: CIS-Mobile-Product-RoamingOverseasData, Predicted: CIS-Mobile-AddOn-Roaming
#
# Sentence: mobile plan roaming
# Ground truth: CIS-Mobile-Product-RoamingOverseasData, Predicted: CIS-Mobile-AddOn-Roaming
#
# Sentence: am i eligible for singtel circle
# Ground truth: CIS-Mobile-Product-SingtelCircle, Predicted: CIS-MobilePlan-EligiblitySingtelCircle
#
# Sentence: what is singtel circle
# Ground truth: CIS-Mobile-Product-SingtelCircle, Predicted: CIS-MobilePlan-EligiblitySingtelCircle
#
# Sentence: can i sign up for singtel circle
# Ground truth: CIS-Mobile-Product-SingtelCircle, Predicted: CIS-MobilePlan-EligiblitySingtelCircle
#
# Sentence: when can i nominate a mobile line
# Ground truth: CIS-Mobile-Product-SingtelCircle, Predicted: CIS-MobilePlan-NoMobilePhone
#
# Sentence: discount for mobile plan in singtel circle
# Ground truth: CIS-Mobile-Product-SingtelCircle, Predicted: CIS-MobilePlan-EligiblitySingtelCircle
#
# Sentence: how much is singtel circle family package
# Ground truth: CIS-Mobile-Product-SingtelCircle, Predicted: CIS-MobilePlan-EligiblitySingtelCircle
#
# Sentence: is there a family package for singtel circle
# Ground truth: CIS-Mobile-Product-SingtelCircle, Predicted: CIS-MobilePlan-EligiblitySingtelCircle
#
# Sentence: is there a package for singtel circle
# Ground truth: CIS-Mobile-Product-SingtelCircle, Predicted: CIS-MobilePlan-EligiblitySingtelCircle
#
# Sentence: singtel circle
# Ground truth: CIS-Mobile-Product-SingtelCircle, Predicted: CIS-MobilePlan-EligiblitySingtelCircle
#
# Sentence: any cis rates for tv
# Ground truth: CIS-Mobile-Product-SingtelTV, Predicted: CIS-Mobile-Product-SingtelTV-PricePlan
#
# Sentence: how much is the monthly subscription for Fox+
# Ground truth: CIS-Mobile-Product-SingtelTV, Predicted: CIS-Mobile-AddOn-CAST-Fox+
#
# Sentence: what is tv go
# Ground truth: CIS-Mobile-Product-SingtelTVGo, Predicted: CIS-Mobile-AddOn-CAST-Fox+
#
# Sentence: i want to know more about singtel tv go
# Ground truth: CIS-Mobile-Product-SingtelTVGo, Predicted: CIS-Mobile-Product-SingtelTV
#
# Sentence: How to sign up for tv go
# Ground truth: CIS-Mobile-Product-SingtelTVGo, Predicted: CIS-Mobile-AddOn-CAST
#
# Sentence: how to set up home view
# Ground truth: CIS-Mobile-Product-SingtelTVGo, Predicted: CIS-Mobile-Product-FibreBroadbandPlans
#
# Sentence: how can i watch singtel tv shows on my mobile
# Ground truth: CIS-Mobile-Product-SingtelTVGo, Predicted: CIS-Mobile-AddOn-CAST-Fox+
#
# Sentence: what are the extra service i can sign up for
# Ground truth: CIS-MobilePlan-AddOn-Menu, Predicted: CIS-Online-DeliveryOptions
#
# Sentence: add-ons
# Ground truth: CIS-MobilePlan-AddOn-Menu, Predicted: CIS-Mobile-AddOn-Free
#
# Sentence: is there any add-ons service??
# Ground truth: CIS-MobilePlan-AddOn-Menu, Predicted: CIS-Mobile-AddOn-Free
#
# Sentence: what value added service does cis have
# Ground truth: CIS-MobilePlan-AddOn-Menu, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: what vas can i sign up with cis
# Ground truth: CIS-MobilePlan-AddOn-Menu, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: i want to sign up other add ons
# Ground truth: CIS-MobilePlan-AddOn-Menu, Predicted: CIS-About-Subsidiary
#
# Sentence: what vas does cis comes free with
# Ground truth: CIS-MobilePlan-AddOn-Menu, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: any vas that cis comes with
# Ground truth: CIS-MobilePlan-AddOn-Menu, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: what vas does cis comes with
# Ground truth: CIS-MobilePlan-AddOn-Menu, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: what vas does cis line have
# Ground truth: CIS-MobilePlan-AddOn-Menu, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: what vas can i sign up for
# Ground truth: CIS-MobilePlan-AddOn-Menu, Predicted: CIS-Mobile-AddOn-CAST-ViuPremium
#
# Sentence: what services can i subscribe to
# Ground truth: CIS-MobilePlan-AddOn-Menu, Predicted: CIS-Mobile-AddOn-SMSMore
#
# Sentence: singtel other services
# Ground truth: CIS-MobilePlan-AddOn-Menu, Predicted: CIS-MobilePlan-EligiblitySingtelCircle
#
# Sentence: how much is the mobile plans under cis
# Ground truth: CIS-MobilePlan-CheckifUnderCIS, Predicted: CIS-MobilePlan-Discount
#
# Sentence: i want to transfer to cis
# Ground truth: CIS-MobilePlan-Convert#How, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: i want to convert to cis
# Ground truth: CIS-MobilePlan-Convert#How, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: convert to cis
# Ground truth: CIS-MobilePlan-Convert#How, Predicted: CIS-MobilePlan-Convert#CorporateToCIS
#
# Sentence: how to transfer to cis
# Ground truth: CIS-MobilePlan-Convert#How, Predicted: CIS-MobilePlan-Convert#CorporateToCIS
#
# Sentence: how to convert to cis
# Ground truth: CIS-MobilePlan-Convert#How, Predicted: CIS-MobilePlan-Convert#CorporateToCIS
#
# Sentence: i want to convert my personal line to cis
# Ground truth: CIS-MobilePlan-Convert#How, Predicted: CIS-MobilePlan-Convert#CorporateToCIS
#
# Sentence: how to convert residential line to cis
# Ground truth: CIS-MobilePlan-Convert#How, Predicted: CIS-MobilePlan-Convert#CorporateToCIS
#
# Sentence: how can i convert my personal line to cis
# Ground truth: CIS-MobilePlan-Convert#How, Predicted: CIS-MobilePlan-Convert#CorporateToCIS
#
# Sentence: i want to transfer my line to singtel
# Ground truth: CIS-MobilePlan-Convert#How, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: how can i convert my line to singtel
# Ground truth: CIS-MobilePlan-Convert#How, Predicted: CIS-MobilePlan-Convert#CorporateToCIS
#
# Sentence: where can i convert my line to cis
# Ground truth: CIS-MobilePlan-Convert#How, Predicted: CIS-MobilePlan-Convert#CorporateToCIS
#
# Sentence: how can i convert my line to cis
# Ground truth: CIS-MobilePlan-Convert#How, Predicted: CIS-MobilePlan-Convert#CorporateToCIS
#
# Sentence: i want to convert my line to cis
# Ground truth: CIS-MobilePlan-Convert#How, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: how do i change my line to cis
# Ground truth: CIS-MobilePlan-Convert#How, Predicted: CIS-MobilePlan-Port-in
#
# Sentence: converting line to cis
# Ground truth: CIS-MobilePlan-Convert#How, Predicted: CIS-MobilePlan-Convert#CorporateToCIS
#
# Sentence: i want to convert my line from personal to CIS
# Ground truth: CIS-MobilePlan-Convert#How, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: can i change to cis
# Ground truth: CIS-MobilePlan-Convert#How, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: how to transfer my line to cis
# Ground truth: CIS-MobilePlan-Convert#How, Predicted: CIS-MobilePlan-Convert#CorporateToCIS
#
# Sentence: i want to transfer my personal line to CIS
# Ground truth: CIS-MobilePlan-Convert#How, Predicted: CIS-MobilePlan-Convert#CorporateToCIS
#
# Sentence: can i transfer my line to CIS
# Ground truth: CIS-MobilePlan-Convert#How, Predicted: CIS-MobilePlan-Convert#CorporateToCIS
#
# Sentence: how can i convert my plan to cis
# Ground truth: CIS-MobilePlan-Convert, Predicted: CIS-MobilePlan-Convert#How
#
# Sentence: how do i convert my plan to cis
# Ground truth: CIS-MobilePlan-Convert, Predicted: CIS-MobilePlan-Convert#How
#
# Sentence: is conversion to cis available at singtel shop
# Ground truth: CIS-MobilePlan-Convert, Predicted: CIS-MobilePlan-Convert#How
#
# Sentence: is there any website i can visit to convert my current plan to cis
# Ground truth: CIS-MobilePlan-Convert, Predicted: CIS-MobilePlan-Convert#How
#
# Sentence: where can i convert my line to cis
# Ground truth: CIS-MobilePlan-Convert, Predicted: CIS-MobilePlan-Convert#CorporateToCIS
#
# Sentence: what should i do to convert my line to cis
# Ground truth: CIS-MobilePlan-Convert, Predicted: CIS-MobilePlan-Convert#How
#
# Sentence: is conversing to cis hard
# Ground truth: CIS-MobilePlan-Convert, Predicted: CIS-MobilePlan-Convert#How
#
# Sentence: how to do conversion from my line to cis
# Ground truth: CIS-MobilePlan-Convert, Predicted: CIS-MobilePlan-Convert#How
#
# Sentence: can i convert my current plan to singtel
# Ground truth: CIS-MobilePlan-Convert, Predicted: CIS-MobilePlan-Convert#How
#
# Sentence: changing plan to cis
# Ground truth: CIS-MobilePlan-Convert, Predicted: CIS-MobilePlan-Convert#How
#
# Sentence: i want to change my plan to cis
# Ground truth: CIS-MobilePlan-Convert, Predicted: CIS-MobilePlan-Convert#How
#
# Sentence: how to convert my plan to cis
# Ground truth: CIS-MobilePlan-Convert, Predicted: CIS-MobilePlan-Convert#How
#
# Sentence: converting line to cis
# Ground truth: CIS-MobilePlan-Convert, Predicted: CIS-MobilePlan-Convert#CorporateToCIS
#
# Sentence: how do i change my line to cis
# Ground truth: CIS-MobilePlan-Convert, Predicted: CIS-MobilePlan-Port-in
#
# Sentence: i want to convert my line from personal/residential to cis
# Ground truth: CIS-MobilePlan-Convert, Predicted: CIS-MobilePlan-Convert#How
#
# Sentence: i want to convert my line to cis
# Ground truth: CIS-MobilePlan-Convert, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: how do i convert my line to cis
# Ground truth: CIS-MobilePlan-Convert, Predicted: CIS-MobilePlan-Convert#How
# Sentence: mobile plan for ernst & young
# Ground truth: CIS-MobilePlan-Discount, Predicted: CIS-Mobile-AddOn-V019
#
# Sentence: What is the corporate discount for 3m technologies?
# Ground truth: CIS-MobilePlan-Discount, Predicted: CIS-Others-Broadband
#
# Sentence: are there any handset discounts
# Ground truth: CIS-MobilePlan-Discount, Predicted: CIS-Others-Broadband
#
# Sentence: how much is combo 2 for HSBC
# Ground truth: CIS-MobilePlan-Discount, Predicted: CIS-Mobile-AddOn-CAST-VarietyPlus
#
# Sentence: what are the discounts like for CIS
# Ground truth: CIS-MobilePlan-Discount, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: is there any cost reduction for subscription
# Ground truth: CIS-MobilePlan-Discount, Predicted: CIS-Online-DeliveryOptions
#
# Sentence: what do i get in return for subscribing
# Ground truth: CIS-MobilePlan-Discount, Predicted: CIS-Promo-Menu
#
# Sentence: how much cost does CIS reduce each month
# Ground truth: CIS-MobilePlan-Discount, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: what are the documents required to sign up for cis
# Ground truth: CIS-MobilePlan-Documents, Predicted: CIS-About-EnrolCriteria
#
# Sentence: is there any documentation i should bring for cis
# Ground truth: CIS-MobilePlan-Documents, Predicted: CIS-HotlineNumber-Service
#
# Sentence: what do i need to bring
# Ground truth: CIS-MobilePlan-Documents, Predicted: smalltalk.agent.can_you_help
#
# Sentence: how many lines can i sign up
# Ground truth: CIS-MobilePlan-EligiblitySingtelCircle, Predicted: CIS-MobilePlan-TotalLines
#
# Sentence: i want to plan my mobile
# Ground truth: CIS-MobilePlan-Menu, Predicted: CIS-MobilePlan-Convert#CorporateToCIS
#
# Sentence: can i arrange for giro payments
# Ground truth: CIS-MobilePlan-Payment-Giro, Predicted: CIS-Online-DeliveryOptions
#
# Sentence: what mobile plans are available for me
# Ground truth: CIS-MobilePlan-Payment, Predicted: CIS-Online-DeliveryOptions
#
# Sentence: how can i sign up for the mobile plans
# Ground truth: CIS-MobilePlan-Payment, Predicted: CIS-Mobile-Product-EnterpriseMobileBundle
#
# Sentence: what are the fees for port in
# Ground truth: CIS-MobilePlan-Port-In-Charges, Predicted: CIS-MobilePlan-Port-in
#
# Sentence: port-in charges
# Ground truth: CIS-MobilePlan-Port-In-Charges, Predicted: CIS-MobilePlan-Port-in
#
# Sentence: is porting in to cis free
# Ground truth: CIS-MobilePlan-Port-In-Charges, Predicted: smalltalk.agent.origin
#
# Sentence: i need to port in. any charges
# Ground truth: CIS-MobilePlan-Port-In-Charges, Predicted: CIS-MobilePlan-Port-in
#
# Sentence: is there any charge if i port out from my old telco
# Ground truth: CIS-MobilePlan-Port-In-Charges, Predicted: CIS-MobilePlan-Port-in
#
# Sentence: port-in payment
# Ground truth: CIS-MobilePlan-Port-In-Charges, Predicted: CIS-MobilePlan-Port-in
#
# Sentence: do i get charges if i port in
# Ground truth: CIS-MobilePlan-Port-In-Charges, Predicted: CIS-MobilePlan-Port-in
#
# Sentence: how much is it to port in
# Ground truth: CIS-MobilePlan-Port-In-Charges, Predicted: CIS-MobilePlan-Port-in
#
# Sentence: what is the charges for number port in
# Ground truth: CIS-MobilePlan-Port-In-Charges, Predicted: CIS-MobilePlan-Port-in
#
# Sentence: how do i port over to m1
# Ground truth: CIS-MobilePlan-PortOut, Predicted: CIS-MobilePlan-Port-in
#
# Sentence: starhub is better
# Ground truth: CIS-MobilePlan-PortOut, Predicted: SmallTalk-Competitors
#
# Sentence: How much is easymobile
# Ground truth: CIS-MobilePlan-RatesEasyMobile, Predicted: CIS-Mobile-AddOn-CAST-ViuPremium
#
# Sentence: yes
# Ground truth: CIS-MobilePlan-RecontractAdminCharges|yes, Predicted: smalltalk.dialog.wrong
#
# Sentence: do it
# Ground truth: CIS-MobilePlan-RecontractAdminCharges|yes, Predicted: smalltalk.greetings.how_are_you
#
# Sentence: sure
# Ground truth: CIS-MobilePlan-RecontractAdminCharges|yes, Predicted: smalltalk.agent.sure
#
# Sentence: exactly
# Ground truth: CIS-MobilePlan-RecontractAdminCharges|yes, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: confirm
# Ground truth: CIS-MobilePlan-RecontractAdminCharges|yes, Predicted: CIS-Online-DeliveryLate
#
# Sentence: of course
# Ground truth: CIS-MobilePlan-RecontractAdminCharges|yes, Predicted: smalltalk.appraisal.bad
#
# Sentence: sounds good
# Ground truth: CIS-MobilePlan-RecontractAdminCharges|yes, Predicted: smalltalk.appraisal.bad
#
# Sentence: that's correct
# Ground truth: CIS-MobilePlan-RecontractAdminCharges|yes, Predicted: smalltalk.agent.right
#
# Sentence: I don't mind
# Ground truth: CIS-MobilePlan-RecontractAdminCharges|yes, Predicted: smalltalk.user.busy
#
# Sentence: I agree
# Ground truth: CIS-MobilePlan-RecontractAdminCharges|yes, Predicted: CIS-MobilePlan-Port-in
#
# Sentence: how can i sign up for ur plan
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-Online-NumberRetention
#
# Sentence: how can i help my employees sign up for cis
# Ground truth: CIS-MobilePlan-SignUp, Predicted: smalltalk.agent.can_you_help
#
# Sentence: how can i sign my parents up for cis
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-MobilePlan-TotalLines
#
# Sentence: where to sign up for CIS
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: tell me how to get cis
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-About-BetterBenefits
#
# Sentence: i want to get cis
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-HotlineNumber-Service
#
# Sentence: how to get cis
# Ground truth: CIS-MobilePlan-SignUp, Predicted: smalltalk.agent.hungry
#
# Sentence: how can i get cis
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: how can i buy cis
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: i just joined a company with cis how to sign up
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-About-Subsidiary
#
# Sentence: i want cis
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-HotlineNumber-Service
#
# Sentence: i want to purchase cis
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: i want to buy cis
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: can i sign up at other singtel shop
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-Online-Vouchers
#
# Sentence: how to go about signing up for cis
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: how do i go about signing up for cis
# Ground truth: CIS-MobilePlan-SignUp, Predicted: smalltalk.agent.can_you_help
#
# Sentence: i want to sign up a plan
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: how to go about signing up a plan
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-Mobile-Product-EnterpriseMobileBundle
#
# Sentence: how can i go about signing up a plan
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-Mobile-Product-EnterpriseMobileBundle
#
# Sentence: how much to sign up
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-Mobile-AddOn-CAST-ViuPremium
#
# Sentence: how can i subscribe to singtel
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-Mobile-Product-SingtelTV
#
# Sentence: how do i subscribe to CIS
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: how can i subscribe to cis
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-MobilePlan-Convert#CorporateToCIS
#
# Sentence: i want to sign up how do i do it
# Ground truth: CIS-MobilePlan-SignUp, Predicted: smalltalk.agent.can_you_help
#
# Sentence: how to sign up to 3 lines
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: how i go about signing up
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-Online-NumberRetention
#
# Sentence: i want to sign up
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: how can i apply for a new plan
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-Mobile-AddOn-V019
#
# Sentence: how do i register for a new plan
# Ground truth: CIS-MobilePlan-SignUp, Predicted: smalltalk.agent.can_you_help
#
# Sentence: how do i register
# Ground truth: CIS-MobilePlan-SignUp, Predicted: smalltalk.agent.can_you_help
#
# Sentence: how do i sign up
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-Online-NumberRetention
#
# Sentence: how to apply
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-About-EnrolCriteria
#
# Sentence: how do i apply
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-MobilePlan-CheckifUnderCIS
#
# Sentence: how do i get myself into the scheme
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-Mobile-Product-EnterpriseMobileBundle
#
# Sentence: how do I sign up?
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-MobilePlan-Port-in
#
# Sentence: where to apply
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-About-EnrolCriteria
#
# Sentence: I want to sign up
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-MobilePlan-SignUp-Individual
#
# Sentence: how to apply for CIS
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-About-EnrolCriteria
#
# Sentence: how can i apply for a CIS line
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-Mobile-AddOn-V019
#
# Sentence: how can i apply for CIS
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-Mobile-AddOn-V019
#
# Sentence: can i sign up for CIS
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: how to sign up for CIS
# Ground truth: CIS-MobilePlan-SignUp, Predicted: CIS-About-EnrolCriteria
#
# Sentence: can i sign up online
# Ground truth: CIS-MobilePlan-SignUpOnline, Predicted: CIS-Promo-OnlineBenefits
#
# Sentence: online sign up
# Ground truth: CIS-MobilePlan-SignUpOnline, Predicted: CIS-Promo-OnlineBenefits
#
# Sentence: sign up online
# Ground truth: CIS-MobilePlan-SignUpOnline, Predicted: CIS-Promo-OnlineBenefits
#
# Sentence: how to sign up online
# Ground truth: CIS-MobilePlan-SignUpOnline, Predicted: CIS-Promo-OnlineBenefits
#
# Sentence: how do i sign up online
# Ground truth: CIS-MobilePlan-SignUpOnline, Predicted: CIS-Promo-OnlineBenefits
# Sentence: please cancel my cis line
# Ground truth: CIS-MobilePlan-TerminateEarly, Predicted: CIS-HotlineNumber-Service
#
# Sentence: cancel my line
# Ground truth: CIS-MobilePlan-TerminateEarly, Predicted: CIS-MobilePlan-Cancellation
#
# Sentence: can i transfer line
# Ground truth: CIS-MobilePlan-TransferOwnership, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: i want to transfer line to mom
# Ground truth: CIS-MobilePlan-TransferOwnership, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: i want to change ownership
# Ground truth: CIS-MobilePlan-TransferOwnership, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: is the free caller ID only for online purcase
# Ground truth: CIS-Online-CallerID-Free, Predicted: CIS-Promo-OnlineBenefits
#
# Sentence: i'm on my combo 2 plan and would like to know the delivery fee
# Ground truth: CIS-Online-DeliveryCharges, Predicted: CIS-Mobile-Product-EnterpriseMobileBundle
#
# Sentence: waive delivery charges
# Ground truth: CIS-Online-DeliveryCharges, Predicted: CIS-Online-DeliveryOptions
#
# Sentence: i want to waive my delivery
# Ground truth: CIS-Online-DeliveryCharges, Predicted: CIS-Online-DeliveryOptions
#
# Sentence: can delivery be waived
# Ground truth: CIS-Online-DeliveryCharges, Predicted: CIS-Online-DeliveryOptions
#
# Sentence: Is delivery free?
# Ground truth: CIS-Online-DeliveryCharges, Predicted: CIS-Online-DeliveryOptions
#
# Sentence: deliver price how much
# Ground truth: CIS-Online-DeliveryCharges, Predicted: CIS-Online-DeliveryOptions
#
# Sentence: are there any delivery charges
# Ground truth: CIS-Online-DeliveryCharges, Predicted: CIS-Online-DeliveryOptions
#
# Sentence: delivery price
# Ground truth: CIS-Online-DeliveryCharges, Predicted: CIS-Online-DeliveryOptions
#
# Sentence: how much will the delivery cost
# Ground truth: CIS-Online-DeliveryCharges, Predicted: CIS-Online-DeliveryOptions
#
# Sentence: delivery how much
# Ground truth: CIS-Online-DeliveryCharges, Predicted: CIS-Online-DeliveryOptions
#
# Sentence: is delivery free
# Ground truth: CIS-Online-DeliveryCharges, Predicted: CIS-Online-DeliveryOptions
#
# Sentence: what is the delivery charge for online purchase / eshop / online cis shop
# Ground truth: CIS-Online-DeliveryCharges, Predicted: CIS-Promo-OnlineBenefits
#
# Sentence: how much is delivery
# Ground truth: CIS-Online-DeliveryCharges, Predicted: CIS-Online-DeliveryOptions
#
# Sentence: is there a home delivery charge?
# Ground truth: CIS-Online-DeliveryCharges, Predicted: CIS-Online-DeliveryOptions
#
# Sentence: for collection at POPStation is there any charge?
# Ground truth: CIS-Online-DeliveryCharges, Predicted: CIS-Online-DeliveryOptions
#
# Sentence: for self-collection is there any charge
# Ground truth: CIS-Online-DeliveryCharges, Predicted: CIS-Online-DeliveryOptions
#
# Sentence: how much is the delivery charge to my home
# Ground truth: CIS-Online-DeliveryCharges, Predicted: CIS-Online-DeliveryOptions
#
# Sentence: how much is the delivery charges
# Ground truth: CIS-Online-DeliveryCharges, Predicted: CIS-Online-DeliveryOptions
#
# Sentence: what are the delivery charges for online purchases
# Ground truth: CIS-Online-DeliveryCharges, Predicted: CIS-Online-DeliveryOptions
#
# Sentence: when will my purchase be delivered
# Ground truth: CIS-Online-DeliveryStatus, Predicted: CIS-Online-DeliveryWhen
#
# Sentence: how can i check my delivery status
# Ground truth: CIS-Online-DeliveryStatus, Predicted: CIS-Online-DeliveryOptions
#
# Sentence: can i check my order online
# Ground truth: CIS-Online-DeliveryStatus, Predicted: CIS-Online-DeliveryOptions
#
# Sentence: online
# Ground truth: CIS-Online-Menu, Predicted: CIS-Promo-OnlineBenefits
#
# Sentence: how to check my singtel onepass
# Ground truth: CIS-Online-OnePass, Predicted: CIS-MobilePlan-ContractStatus-SingtelOnePass
#
# Sentence: there is an issue in online purchasing
# Ground truth: CIS-Online-Purchase-Problem, Predicted: CIS-Promo-OnlineBenefits
#
# Sentence: internet purchasing
# Ground truth: CIS-Online-Purchase, Predicted: CIS-Online-Purchase-Problem
#
# Sentence: i want to shop on stream
# Ground truth: CIS-Online-Purchase, Predicted: CIS-Mobile-AddOn-CAST-SportsPlus
#
# Sentence: can i e-shop
# Ground truth: CIS-Online-Purchase, Predicted: CIS-Mobile-Product-EnterpriseMobileBundle
#
# Sentence: is electronic shop available here
# Ground truth: CIS-Online-Purchase, Predicted: CIS-Mobile-Product-EnterpriseMobileBundle
#
# Sentence: can i purchase cis phone online
# Ground truth: CIS-Online-Purchase, Predicted: CIS-MobilePlan-NoMobilePhone
#
# Sentence: can i buy a phone online
# Ground truth: CIS-Online-Purchase, Predicted: CIS-MobilePlan-NoMobilePhone
#
# Sentence: how to buy online
# Ground truth: CIS-Online-Purchase, Predicted: CIS-Mobile-Product-SingtelOnlineGifts
#
# Sentence: where can i buy online
# Ground truth: CIS-Online-Purchase, Predicted: CIS-Mobile-Product-SingtelOnlineGifts
#
# Sentence: how can i buy online
# Ground truth: CIS-Online-Purchase, Predicted: CIS-Mobile-Product-SingtelOnlineGifts
#
# Sentence: how do i purchase online
# Ground truth: CIS-Online-Purchase, Predicted: CIS-Mobile-Product-EnterpriseMobileBundle
#
# Sentence: can i purchase online
# Ground truth: CIS-Online-Purchase, Predicted: CIS-Mobile-Product-EnterpriseMobileBundle
#
# Sentence: can i buy online
# Ground truth: CIS-Online-Purchase, Predicted: CIS-Mobile-Product-SingtelOnlineGifts
#
# Sentence: i got no link
# Ground truth: CIS-Online-Troubleshoot, Predicted: CIS-Online-TroubleshootOTP
#
# Sentence: live chat
# Ground truth: CIS-Online-Troubleshoot, Predicted: CIS-Online-TroubleshootChatAgent
#
# Sentence: live web chat
# Ground truth: CIS-Online-Troubleshoot, Predicted: CIS-Online-TroubleshootChatAgent
#
# Sentence: i want to talk to your live chat agent
# Ground truth: CIS-Online-Troubleshoot, Predicted: CIS-Online-TroubleshootChatAgent
#
# Sentence: what is the live chat agent website
# Ground truth: CIS-Online-Troubleshoot, Predicted: CIS-Online-TroubleshootChatAgent
#
# Sentence: where is your live chat agent
# Ground truth: CIS-Online-Troubleshoot, Predicted: CIS-Online-TroubleshootChatAgent
#
# Sentence: live chat agent
# Ground truth: CIS-Online-Troubleshoot, Predicted: CIS-Online-TroubleshootChatAgent
#
# Sentence: where is your chat agent
# Ground truth: CIS-Online-Troubleshoot, Predicted: CIS-Online-TroubleshootChatAgent
#
# Sentence: where is your online chat agent
# Ground truth: CIS-Online-Troubleshoot, Predicted: CIS-Online-Purchase-Problem
#
# Sentence: were is your chat agent
# Ground truth: CIS-Online-Troubleshoot, Predicted: CIS-Online-TroubleshootChatAgent
#
# Sentence: i want to talk to chat agent
# Ground truth: CIS-Online-Troubleshoot, Predicted: CIS-Online-TroubleshootChatAgent
#
# Sentence: how to talk to online chat agent
# Ground truth: CIS-Online-Troubleshoot, Predicted: CIS-Online-TroubleshootChatAgent
#
# Sentence: i would like to speak with an online chat agent
# Ground truth: CIS-Online-Troubleshoot, Predicted: CIS-Online-TroubleshootChatAgent
#
# Sentence: i got no email address to sign up
# Ground truth: CIS-Online-Troubleshoot, Predicted: CIS-Others-Email
#
# Sentence: i don't have an email account to sign up
# Ground truth: CIS-Online-Troubleshoot, Predicted: CIS-Online-TroubleshootOTP
#
# Sentence: i got no email to sign up
# Ground truth: CIS-Online-Troubleshoot, Predicted: CIS-Online-TroubleshootOTP
#
# Sentence: i don't have a email address to sign up
# Ground truth: CIS-Online-Troubleshoot, Predicted: CIS-Online-TroubleshootOTP
#
# Sentence: me no email
# Ground truth: CIS-Online-Troubleshoot, Predicted: CIS-Others-Email
#
# Sentence: i dont have an email to sign up
# Ground truth: CIS-Online-Troubleshoot, Predicted: CIS-Online-TroubleshootOTP
#
# Sentence: where to talk to chat agent
# Ground truth: CIS-Online-Troubleshoot, Predicted: CIS-Online-TroubleshootChatAgent
#
# Sentence: online chat agent
# Ground truth: CIS-Online-Troubleshoot, Predicted: CIS-Online-TroubleshootChatAgent
#
# Sentence: i want to speak to an chat agent
# Ground truth: CIS-Online-Troubleshoot, Predicted: CIS-Online-TroubleshootChatAgent
#
# Sentence: i got no email
# Ground truth: CIS-Online-Troubleshoot, Predicted: CIS-Online-TroubleshootOTP
#
# ...
# Ground truth: CIS-Others-Human, Predicted: smalltalk.user.does_not_want_to_talk
#
# Sentence: stop saying do not understand!
# Ground truth: CIS-Others-Human, Predicted: CIS-HotlineNumber-Service
#
# Sentence: ask a human to call me
# Ground truth: CIS-Others-Human, Predicted: CIS-HotlineNumber-Service
#
# Sentence: where is your humans
# Ground truth: CIS-Others-Human, Predicted: smalltalk.agent.origin
#
# Sentence: i want a human
# Ground truth: CIS-Others-Human, Predicted: smalltalk.dialog.hug
#
# Sentence: i don't want to talk to a bot
# Ground truth: CIS-Others-Human, Predicted: smalltalk.user.does_not_want_to_talk
#
# Sentence: can u give me a voucher
# Ground truth: CIS-Others-LoyalCustomer, Predicted: smalltalk.agent.can_you_help
#
# Sentence: can i have a voucher
# Ground truth: CIS-Others-LoyalCustomer, Predicted: CIS-MobilePlan-NoMobilePhone
#
# Sentence: do i get any recompense for being a cis user
# Ground truth: CIS-Others-LoyalCustomer, Predicted: CIS-HotlineNumber-Service
# Sentence: what can customers get in return for using cis
# Ground truth: CIS-Others-LoyalCustomer, Predicted: CIS-HotlineNumber-Service
#
# Sentence: is there an upcoming flash sale
# Ground truth: CIS-Others-Newsletter, Predicted: CIS-Promo-Next
#
# Sentence: any other promotions roadshows
# Ground truth: CIS-Others-Roadshow, Predicted: CIS-Promo-Menu
#
# Sentence: any free early recontract
# Ground truth: CIS-Promo-Latest, Predicted: CIS-Promo-Menu
#
# Sentence: i want to know when is the next promotion
# Ground truth: CIS-Promo-Next, Predicted: CIS-Others-Newsletter
#
# Sentence: why still no news on CIS Flash Online Sales
# Ground truth: CIS-Promo-Next, Predicted: CIS-Promo-OnlineBenefits
#
# Sentence: i want to know the next flash sale
# Ground truth: CIS-Promo-Next, Predicted: CIS-Others-Newsletter
#
# Sentence: when is the next flash sale
# Ground truth: CIS-Promo-Next, Predicted: CIS-Others-Newsletter
#
# Sentence: are you a bot
# Ground truth: SmallTalk-Availability, Predicted: smalltalk.agent.chatbot
#
# Sentence: do you hear me
# Ground truth: SmallTalk-Availability, Predicted: smalltalk.agent.can_you_help
#
# Sentence: still there
# Ground truth: SmallTalk-Availability, Predicted: smalltalk.agent.there
#
# Sentence: are you there
# Ground truth: SmallTalk-Availability, Predicted: smalltalk.agent.there
#
# Sentence: singtel not good
# Ground truth: SmallTalk-SingtelLousy, Predicted: smalltalk.appraisal.bad
#
# Sentence: who are u
# Ground truth: Smalltalk-Who, Predicted: smalltalk.agent.boss
#
# Sentence: who are you
# Ground truth: Smalltalk-Who, Predicted: smalltalk.agent.acquaintance
#
# Sentence: are you a human
# Ground truth: Smalltalk-Who, Predicted: smalltalk.agent.real
#
# Sentence: what is your occupation
# Ground truth: Smalltalk-Who, Predicted: smalltalk.gender
#
# Sentence: what is your job
# Ground truth: Smalltalk-Who, Predicted: smalltalk.gender
#
# Sentence: are you real
# Ground truth: Smalltalk-Who, Predicted: smalltalk.agent.real
#
# Sentence: what's your name
# Ground truth: Smalltalk-Who, Predicted: smalltalk.agent.origin
#
# Sentence: brilliant
# Ground truth: smalltalk.agent.clever, Predicted: smalltalk.appraisal.good
#
# Sentence: you're sick
# Ground truth: smalltalk.agent.crazy, Predicted: smalltalk.agent.bad
#
# Sentence: you are crazy
# Ground truth: smalltalk.agent.crazy, Predicted: smalltalk.agent.bad
#
# Sentence: you are mad
# Ground truth: smalltalk.agent.crazy, Predicted: smalltalk.agent.bad
#
# Sentence: you are very helpful
# Ground truth: smalltalk.agent.good, Predicted: smalltalk.agent.beautiful
#
# Sentence: you are good
# Ground truth: smalltalk.agent.good, Predicted: smalltalk.agent.bad
#
# Sentence: you are a professional
# Ground truth: smalltalk.agent.good, Predicted: smalltalk.agent.clever
#
# Sentence: you're perfect
# Ground truth: smalltalk.agent.good, Predicted: smalltalk.agent.beautiful
#
# Sentence: you're great
# Ground truth: smalltalk.agent.good, Predicted: smalltalk.agent.beautiful
#
# Sentence: you're so kind
# Ground truth: smalltalk.agent.good, Predicted: smalltalk.agent.beautiful
#
# Sentence: you are amazing
# Ground truth: smalltalk.agent.good, Predicted: smalltalk.agent.beautiful
#
# Sentence: you are awesome
# Ground truth: smalltalk.agent.good, Predicted: smalltalk.agent.beautiful
#
# Sentence: you are really good
# Ground truth: smalltalk.agent.good, Predicted: smalltalk.agent.beautiful
#
# Sentence: you are really nice
# Ground truth: smalltalk.agent.good, Predicted: smalltalk.agent.beautiful
#
# Sentence: you are so amazing
# Ground truth: smalltalk.agent.good, Predicted: smalltalk.agent.beautiful
#
# Sentence: you are so awesome
# Ground truth: smalltalk.agent.good, Predicted: smalltalk.agent.beautiful
#
# Sentence: you are so cool
# Ground truth: smalltalk.agent.good, Predicted: smalltalk.agent.beautiful
#
# Sentence: you are so fine
# Ground truth: smalltalk.agent.good, Predicted: smalltalk.agent.beautiful
#
# Sentence: you are so good
# Ground truth: smalltalk.agent.good, Predicted: smalltalk.agent.beautiful
#
# Sentence: you are so helpful
# Ground truth: smalltalk.agent.good, Predicted: smalltalk.agent.beautiful
#
# Sentence: you are so lovely
# Ground truth: smalltalk.agent.good, Predicted: smalltalk.agent.beautiful
#
# Sentence: you are too good
# Ground truth: smalltalk.agent.good, Predicted: smalltalk.agent.beautiful
#
# Sentence: you are very kind
# Ground truth: smalltalk.agent.good, Predicted: smalltalk.agent.beautiful
#
# Sentence: you are very lovely
# Ground truth: smalltalk.agent.good, Predicted: smalltalk.agent.beautiful
#
# Sentence: you are very useful
# Ground truth: smalltalk.agent.good, Predicted: smalltalk.agent.beautiful
#
# Sentence: you are wonderful
# Ground truth: smalltalk.agent.good, Predicted: smalltalk.agent.beautiful
#
# Sentence: you made my day
# Ground truth: smalltalk.agent.good, Predicted: smalltalk.greetings.how_are_you
#
# Sentence: you rock
# Ground truth: smalltalk.agent.good, Predicted: smalltalk.agent.beautiful
#
# Sentence: you are really amazing
# Ground truth: smalltalk.agent.good, Predicted: smalltalk.agent.beautiful
#
# Sentence: that's true
# Ground truth: smalltalk.agent.right, Predicted: smalltalk.appraisal.bad
#
# Sentence: you're not wrong
# Ground truth: smalltalk.agent.right, Predicted: smalltalk.agent.bad
#
# Sentence: it's the truth
# Ground truth: smalltalk.agent.right, Predicted: smalltalk.appraisal.bad
#
# Sentence: it's true
# Ground truth: smalltalk.agent.right, Predicted: smalltalk.appraisal.bad
#
# Sentence: that's so true
# Ground truth: smalltalk.agent.right, Predicted: smalltalk.appraisal.bad
#
# Sentence: Ok then
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.emotions.ha_ha
#
# Sentence: so cool
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: that is good
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: it's amazing
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: that's awesome
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: perfect
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.agent.beautiful
#
# Sentence: that's great
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: it's good
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: it's great
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: good
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: that's fine
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: very good
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: good very good
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: that's very good
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: it is fine
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: it is good
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: it's great
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: it's perfect
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: not bad
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: not too bad
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: it's very good
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: that's nice
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: pretty good
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.agent.beautiful
#
# Sentence: straight
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.greetings.goodnight
#
# Sentence: that was cute
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.agent.beautiful
#
# Sentence: that was pretty good
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: that was very good
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: that's a good idea
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: that's a good thing
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: that's amazing
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: that's better
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: that's cute
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: that's fantastic
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: that's much better
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: that's nice of you
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: that's not bad
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: that's perfect
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: that's pretty good
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: that's really good
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: that's really nice
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: that's sweet of you
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: that's very nice
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
# Sentence: that's wonderful
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: this is good
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: this is great
# Ground truth: smalltalk.appraisal.good, Predicted: CIS-Mobile-AddOn-CAST-VarietyPlus
#
# Sentence: very then
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: I'm glad to hear that
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.user.excited
#
# Sentence: ok good
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: good for you
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.greetings.goodnight
#
# Sentence: glad to hear it
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.greetings.nice_to_see_you
#
# Sentence: so good
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: it was good
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: oh well
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.emotions.ha_ha
#
# Sentence: good thing
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: that was good
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: it's awesome
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: okay good
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: it's fine
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: no it's okay
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: that's great
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: it's very good
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: that's fine
# Ground truth: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: I appreciate it
# Ground truth: smalltalk.appraisal.thank_you, Predicted: smalltalk.user.loves_agent
#
# Sentence: I thank you
# Ground truth: smalltalk.appraisal.thank_you, Predicted: smalltalk.user.loves_agent
#
# Sentence: thank you that will be all
# Ground truth: smalltalk.appraisal.thank_you, Predicted: smalltalk.agent.can_you_help
#
# Sentence: thank you my friend
# Ground truth: smalltalk.appraisal.thank_you, Predicted: smalltalk.agent.my_friend
#
# Sentence: thank you again
# Ground truth: smalltalk.appraisal.thank_you, Predicted: smalltalk.user.wants_to_see_agent_again
#
# Sentence: no thank you that's all
# Ground truth: smalltalk.appraisal.thank_you, Predicted: smalltalk.agent.can_you_help
#
# Sentence: so nice of you
# Ground truth: smalltalk.appraisal.thank_you, Predicted: smalltalk.appraisal.good
#
# Sentence: You gave an irrelevant answer.
# Ground truth: smalltalk.dialog.sorry, Predicted: smalltalk.dialog.wrong
#
# Sentence: here I am
# Ground truth: smalltalk.user.here, Predicted: smalltalk.user.back
#
# Sentence: I am joking
# Ground truth: smalltalk.user.joking, Predicted: smalltalk.user.sad
#
# Sentence: I liked you
# Ground truth: smalltalk.user.likes_agent, Predicted: smalltalk.user.loves_agent
#
# Sentence: you are very special
# Ground truth: smalltalk.user.likes_agent, Predicted: smalltalk.agent.beautiful
#
# Sentence: you are so sweet
# Ground truth: smalltalk.user.likes_agent, Predicted: smalltalk.agent.beautiful
#
# Sentence: you are very special to me
# Ground truth: smalltalk.user.likes_agent, Predicted: smalltalk.agent.my_friend
#
# Sentence: I do like you
# Ground truth: smalltalk.user.likes_agent, Predicted: smalltalk.agent.can_you_help
#
# Sentence: you are special for me
# Ground truth: smalltalk.user.likes_agent, Predicted: smalltalk.agent.my_friend
#
# Sentence: you are so special
# Ground truth: smalltalk.user.likes_agent, Predicted: smalltalk.agent.beautiful
#
# Sentence: I said I like you
# Ground truth: smalltalk.user.likes_agent, Predicted: smalltalk.user.looks_like
#
# Sentence: you're so special
# Ground truth: smalltalk.user.likes_agent, Predicted: smalltalk.agent.beautiful
#
# Sentence: I like your smile
# Ground truth: smalltalk.user.likes_agent, Predicted: smalltalk.user.looks_like
#
# Sentence: I kinda like you
# Ground truth: smalltalk.user.likes_agent, Predicted: smalltalk.user.looks_like
#
# Sentence: you are really special
# Ground truth: smalltalk.user.likes_agent, Predicted: smalltalk.agent.beautiful
#
# Sentence: I really do like you
# Ground truth: smalltalk.user.likes_agent, Predicted: smalltalk.agent.can_you_help
#
# Sentence: I really really really really like you
# Ground truth: smalltalk.user.likes_agent, Predicted: smalltalk.user.looks_like
#
# Sentence: I am lonely
# Ground truth: smalltalk.user.lonely, Predicted: smalltalk.user.sad
#
# Sentence: I am feeling lonely
# Ground truth: smalltalk.user.lonely, Predicted: smalltalk.user.sad
#
# Sentence: I need advice
# Ground truth: smalltalk.user.needs_advice, Predicted: smalltalk.agent.can_you_help
#
# Sentence: suck my cock
# Ground truth: smalltalk.user.pleasure, Predicted: smalltalk.vulgarities
#
# Sentence: let's have sex
# Ground truth: smalltalk.user.pleasure, Predicted: smalltalk.agent.sex
#
# Sentence: speak with me
# Ground truth: smalltalk.user.wants_to_talk, Predicted: smalltalk.agent.talk_to_me
#
# Sentence: you are not intelligent
# Ground truth: smalltalk.vulgarities, Predicted: smalltalk.agent.bad
#
# Sentence: you are stupid
# Ground truth: smalltalk.vulgarities, Predicted: smalltalk.agent.bad

# %%
BOTBOT_CHATLOG_PATH = path.join(BASE_PATH, 'data/botbot/francis_ChatLogExport.csv')

# %%
import csv
CHATLOG_DATA = []
with open(BOTBOT_CHATLOG_PATH, 'r') as csvfile:
    reader = csv.reader(csvfile)
    rows = 0
    keys = []
    for row in reader:
        if rows == 0:
            keys = row
        else:
            item = {}
            for idx, key_name in enumerate(keys):
                item[key_name] = row[idx]
            CHATLOG_DATA.append(item)
        rows += 1

# %%
CHATLOG_DATA[3]
# Out:
# {'Channel': 'directline',
#  'From': '',
#  'Intent': 'CIS-Greetings',
#  'Score': '1',
#  'Text Reply': 'Hi, I\'m FranCIS. How can I help you today with your CIS enquiries? You can say "menu" at any time to pull out the menu options again.',
#  'User Message': 'User clicked on a button Hello'}

# %%
total = 0
correct = 0

for log_item in CHATLOG_DATA:
    user_msg = log_item.get('User Message', None)
    intent_txt = log_item.get('Intent', None)
    if user_msg and intent_txt:
        if not (len(user_msg) > 6 and user_msg[:5] == '|-|#|'): # skips
            if len(user_msg) > 25 and user_msg[:25] == 'User clicked on a button ':
                user_msg = user_msg[25:]
            if intent_txt != 'Default Fallback Intent' and intent_txt in classes \
                and user_msg.lower() not in ['hello', 'hi']:
                total += 1
                # Get DF class index
                intent_cls = classes.index(intent_txt)
                
                # Get own model class index
                precheck_sent = process_sentences([user_msg])
                pred_class = argmax(model(*precheck_sent))
                
                if intent_cls != pred_class:
                    print('Sentence: %s' % user_msg)
                    print('Dialogflow: %s, Predicted: %s\r\n' % (classes[intent_cls], classes[pred_class]))
                else:
                    correct += 1

print('Accuracy: %s - Correct predictions: %s out of %s' % (str(float(correct) / float(total)), correct, total))
# Out:
# Sentence: i want to port our
# Dialogflow: CIS-MobilePlan-PortOut, Predicted: CIS-MobilePlan-Port-in
#
# Sentence: I hate u
# Dialogflow: SmallTalk-SingtelLousy, Predicted: smalltalk.user.misses_agent
#
# Sentence: i hate you
# Dialogflow: SmallTalk-SingtelLousy, Predicted: smalltalk.user.misses_agent
#
# Sentence: i want to port of
# Dialogflow: CIS-MobilePlan-PortOut, Predicted: CIS-MobilePlan-Port-in
#
# Sentence: Okay. So, tell me a little bit about FranCIS
# Dialogflow: CIS-Others-DepositForForeigners, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: Why do you call yourself FranCIS?
# Dialogflow: SmallTalk-Identity, Predicted: smalltalk.agent.acquaintance
#
# Sentence: well, i have 199
# Dialogflow: smalltalk.appraisal.good, Predicted: CIS-MobilePlan-Convert-1st
#
# Sentence: criteria to enrol inc is
# Dialogflow: CIS-About-EnrolCriteria, Predicted: CIS-MobilePlan-ConvertFees
#
# Sentence: my baby got a cold
# Dialogflow: CIS-About-MenuWhatIsBenefits, Predicted: smalltalk.user.bored
#
# Sentence: my baby got a cold
# Dialogflow: CIS-About-MenuWhatIsBenefits, Predicted: smalltalk.user.bored
#
# Sentence: my baby got a cold
# Dialogflow: CIS-About-MenuWhatIsBenefits, Predicted: smalltalk.user.bored
#
# Sentence: hi guys
# Dialogflow: CIS-Others-DepositForForeigners, Predicted: smalltalk.emotions.ha_ha
#
# Sentence: Hi, regarding samsung 8+, if i choose gray color online but decided to change to another color at the Singtel shop, is it ok?
# Dialogflow: CIS-Devices, Predicted: CIS-Devices-Note8
#
# Sentence: how to visit your website
# Dialogflow: CIS-Others-Website, Predicted: CIS-Others-Email
#
# Sentence: I just book an appointment for purchase of Note 8. Is it necessary to input company email address?
# Dialogflow: CIS-Online-Troubleshoot, Predicted: CIS-Online-TroubleshootOTP
#
# Sentence: Is it possible if you check how much is s8 plus if I take a new contract of combo 4 or 5
# Dialogflow: CIS-Devices, Predicted: CIS-MobilePlan-Convert-1st
#
# Sentence: is my company eligible?
# Dialogflow: CIS-About-EnrolCriteria, Predicted: CIS-About-CompanyEnrollment
#
# Sentence: mobile phone colour
# Dialogflow: CIS-Devices-Menu, Predicted: CIS-MobilePlan-NoMobilePhone
#
# Sentence: mobile share
# Dialogflow: CIS-Mobile-AddOn-MobileShare, Predicted: CIS-MobilePlan-RatesEasyMobile
#
# Sentence: no email address
# Dialogflow: CIS-Online-Troubleshoot, Predicted: CIS-Others-Email
#
# Sentence: note 8 pre order
# Dialogflow: CIS-Devices, Predicted: CIS-Devices-Note8
#
# Sentence: Note 8 pre order
# Dialogflow: CIS-Devices, Predicted: CIS-Devices-Note8
#
# Sentence: okay.. :(
# Dialogflow: smalltalk.greetings.how_are_you, Predicted: smalltalk.emotions.ha_ha
#
# Sentence: Preorder of Note 8
# Dialogflow: CIS-Devices, Predicted: CIS-Devices-Note8
#
# Sentence: mobile share
# Dialogflow: CIS-Mobile-AddOn-MobileShare, Predicted: CIS-MobilePlan-RatesEasyMobile
#
# Sentence: Hello Francis
# Dialogflow: CIS-Greetings, Predicted: CIS-Menu
#
# Sentence: New message
# Dialogflow: CIS-Promo-Next, Predicted: CIS-MobilePlan-NewPlan
#
# Sentence: Hey there
# Dialogflow: CIS-Greetings, Predicted: SmallTalk-Availability
#
# Sentence: helloo
# Dialogflow: CIS-Greetings, Predicted: SmallTalk-Weather
#
# Sentence: how do I sign up?
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-MobilePlan-Port-in
#
# Sentence: hi May
# Dialogflow: CIS-Greetings, Predicted: CIS-Others-FEB
#
# Sentence:  just want to ask the status of my order?
# Dialogflow: CIS-Online-DeliveryStatus, Predicted: CIS-Online-Authorisation
#
# Sentence: just want to ask the status of my order?
# Dialogflow: CIS-Online-DeliveryStatus, Predicted: CIS-Online-Authorisation
#
# Sentence: what is your name?
# Dialogflow: CIS-Greetings, Predicted: SmallTalk-Identity
#
# Sentence: francis is smart dud
# Dialogflow: smalltalk.agent.clever, Predicted: CIS-Mobile-AddOn-ZoneAlarm
#
# Sentence: i hate you
# Dialogflow: SmallTalk-SingtelLousy, Predicted: smalltalk.user.misses_agent
#
# Sentence: I really hate you
# Dialogflow: SmallTalk-SingtelLousy, Predicted: CIS-HotlineNumber-Service
#
# Sentence: Hello FranCIS
# Dialogflow: CIS-Greetings, Predicted: CIS-Menu
#
# Sentence: hey
# Dialogflow: CIS-Greetings, Predicted: smalltalk.emotions.ha_ha
#
# Sentence: hello there
# Dialogflow: CIS-Greetings, Predicted: CIS-Menu
#
# Sentence: who are you
# Dialogflow: Smalltalk-Who, Predicted: smalltalk.agent.acquaintance
#
# Sentence: Nhat has a fat belluy
# Dialogflow: CIS-About-CompanyEnrollment, Predicted: smalltalk.vulgarities
#
# Sentence: c'mon Ngoc come
# Dialogflow: CIS-MobilePlan-RecontractAdminCharges-21st, Predicted: CIS-MobilePlan-SignUp-NSFandOthers
#
# Sentence: Nhat has a fat belly
# Dialogflow: CIS-About-CompanyEnrollment, Predicted: smalltalk.gender
#
# Sentence: how about in store CIS promotion
# Dialogflow: CIS-Promo-Extend, Predicted: CIS-About-MenuWhatIsBenefits
#
# Sentence: sign up for mobile share
# Dialogflow: CIS-Mobile-AddOn-MobileShare, Predicted: CIS-MobilePlan-Payment
#
# Sentence: hi, i cannot complete my transaction to port over my starhub tel to singtel
# Dialogflow: CIS-MobilePlan-Port-in, Predicted: CIS-MobilePlan-PortOut
#
# Sentence: how do i complete my purchase online?
# Dialogflow: CIS-Online-Purchase, Predicted: CIS-Online-TradeIn
#
# Sentence: Hi. What promotions will AIA employees be entitled to?
# Dialogflow: CIS-Promo-Menu, Predicted: CIS-Mobile-Product-EnterpriseMobileBundle
#
# Sentence: how to check iphone stock
# Dialogflow: CIS-Devices, Predicted: CIS-Devices-LatestIphone
#
# Sentence: stock availability for samsung phone?
# Dialogflow: CIS-Devices, Predicted: CIS-Mobile-AddOn-SamsungConcierge
#
# Sentence: I am getting a new hp
# Dialogflow: CIS-Devices, Predicted: CIS-Mobile-AddOn-Roaming
#
# Sentence: is singapore airlines in this
# Dialogflow: CIS-About-CompanyEnrollment, Predicted: CIS-Online-TradeIn
#
# Sentence: I from SQ can i apply for a line
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-Mobile-AddOn-V019
#
# Sentence: how do I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-Online-NumberRetention
#
# Sentence: how do I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-Online-NumberRetention
#
# Sentence: how do I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-Online-NumberRetention
#
# Sentence: how do I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-Online-NumberRetention
#
# Sentence: how do I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-Online-NumberRetention
#
# Sentence: how do I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-Online-NumberRetention
#
# Sentence: how do I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-Online-NumberRetention
#
# Sentence: how do I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-Online-NumberRetention
#
# Sentence: I hate you
# Dialogflow: SmallTalk-SingtelLousy, Predicted: smalltalk.user.misses_agent
#
# Sentence: I hate you
# Dialogflow: SmallTalk-SingtelLousy, Predicted: smalltalk.user.misses_agent
#
# Sentence: I hate you
# Dialogflow: SmallTalk-SingtelLousy, Predicted: smalltalk.user.misses_agent
#
# Sentence: I hate you
# Dialogflow: SmallTalk-SingtelLousy, Predicted: smalltalk.user.misses_agent
#
# Sentence: say hi
# Dialogflow: smalltalk.agent.talk_to_me, Predicted: CIS-Greetings
#
# Sentence: say hi
# Dialogflow: smalltalk.agent.talk_to_me, Predicted: CIS-Greetings
#
# Sentence: ask how do I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: smalltalk.agent.can_you_help
#
# Sentence: how do I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-Online-NumberRetention
#
# Sentence: how do I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-Online-NumberRetention
#
# Sentence: how can I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: how can I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: how can I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: go to Patel from M1
# Dialogflow: CIS-MobilePlan-Port-in, Predicted: CIS-Mobile-AddOn-DataX2
#
# Sentence: can I just say
# Dialogflow: smalltalk.agent.talk_to_me, Predicted: smalltalk.agent.can_you_help
#
# Sentence: what discounts to I get
# Dialogflow: CIS-MobilePlan-Discount, Predicted: CIS-Promo-Menu
#
# Sentence: how can I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: what is the phone number
# Dialogflow: CIS-Devices, Predicted: CIS-Mobile-AddOn-ZoneAlarm
#
# Sentence: how do I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-Online-NumberRetention
#
# Sentence: how do I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-Online-NumberRetention
#
# Sentence: yes please
# Dialogflow: SmallTalk-Please, Predicted: CIS-About-CompanyEnrollment#Less200
#
# Sentence: not that station
# Dialogflow: smalltalk.dialog.wrong, Predicted: smalltalk.appraisal.bad
#
# Sentence: what are the discount available
# Dialogflow: CIS-MobilePlan-Discount, Predicted: CIS-Online-DeliveryOptions
#
# Sentence: what can you do for me
# Dialogflow: CIS-Menu, Predicted: smalltalk.agent.can_you_help
#
# Sentence: who created you
# Dialogflow: Smalltalk-Who, Predicted: smalltalk.agent.boss
#
# Sentence: are you a bot
# Dialogflow: SmallTalk-Availability, Predicted: smalltalk.agent.chatbot
#
# Sentence: who are you
# Dialogflow: Smalltalk-Who, Predicted: smalltalk.agent.acquaintance
#
# Sentence: how can I say
# Dialogflow: smalltalk.agent.talk_to_me, Predicted: smalltalk.user.wants_to_talk
#
# Sentence: how can I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: how can I can thank you
# Dialogflow: smalltalk.appraisal.thank_you, Predicted: smalltalk.agent.can_you_help
#
# Sentence: tell us a joke
# Dialogflow: smalltalk.user.joking, Predicted: smalltalk.dialog.hug
#
# Sentence: how can I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: open francie's bot
# Dialogflow: smalltalk.agent.chatbot, Predicted: smalltalk.user.wants_to_talk
#
# Sentence: in the website
# Dialogflow: CIS-MobilePlan-Port-in|Online, Predicted: CIS-Online-TroubleshootChatAgent
#
# Sentence: how can I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: how can I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: open Francis
# Dialogflow: CIS-Menu, Predicted: smalltalk.vulgarities
#
# Sentence: how do I sign up for fences
# Dialogflow: CIS-Others-Dash-General, Predicted: CIS-Online-NumberRetention
#
# Sentence: how do I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-Online-NumberRetention
#
# Sentence: yes
# Dialogflow: CIS-MobilePlan-RecontractAdminCharges|yes, Predicted: smalltalk.dialog.wrong
#
# Sentence: what are your favorite foods
# Dialogflow: smalltalk.favourites, Predicted: smalltalk.agent.hobby
#
# Sentence: how do I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-Online-NumberRetention
#
# Sentence: how do I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-Online-NumberRetention
#
# Sentence: how do I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-Online-NumberRetention
#
# Sentence: tell me a joke
# Dialogflow: smalltalk.user.joking, Predicted: smalltalk.vulgarities
# Sentence: tell me a joke
# Dialogflow: smalltalk.user.joking, Predicted: smalltalk.vulgarities
#
# Sentence: who are you
# Dialogflow: Smalltalk-Who, Predicted: smalltalk.agent.acquaintance
#
# Sentence: you know Alexa
# Dialogflow: smalltalk.agent.clever, Predicted: CIS-Menu
#
# Sentence: can we carrying
# Dialogflow: smalltalk.user.wants_to_talk, Predicted: CIS-About-CompanyEnrollment#Less200
#
# Sentence: how do I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-Online-NumberRetention
#
# Sentence: how much do I have to pay for the plains
# Dialogflow: CIS-Mobile-Product-SingtelCircle, Predicted: CIS-MobilePlan-ConvertFees
#
# Sentence: wife is late
# Dialogflow: CIS-Online-DeliveryLate, Predicted: CIS-MobilePlan-RecontractEarly
#
# Sentence: can you sure set was the question
# Dialogflow: CIS-MobilePlan-RecontractAdminCharges|yes, Predicted: smalltalk.agent.beautiful
#
# Sentence: yes hi
# Dialogflow: CIS-MobilePlan-RecontractAdminCharges|yes, Predicted: smalltalk.appraisal.thank_you
#
# Sentence: i signed up on 4 july 2017 , can i upgrade my device ?
# Dialogflow: CIS-MobilePlan-RecontractDeviceUpgradeCharges, Predicted: CIS - Mobile Plan - Recontract TEST
#
# Sentence: how can I sign up
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: i want to convert to cis
# Dialogflow: CIS-MobilePlan-Convert#How, Predicted: CIS-MobilePlan-Convert#CMESToCIS
#
# Sentence: what is your name
# Dialogflow: CIS-Greetings, Predicted: smalltalk.gender
#
# Sentence: yes
# Dialogflow: CIS-MobilePlan-RecontractAdminCharges|yes, Predicted: smalltalk.dialog.wrong
#
# Sentence: what is your name?
# Dialogflow: CIS-Greetings, Predicted: SmallTalk-Identity
#
# Sentence: what documents do i need
# Dialogflow: CIS-MobilePlan-Documents, Predicted: CIS-MobilePlan-Documents#Online
#
# Sentence: what documents do i need
# Dialogflow: CIS-MobilePlan-Documents, Predicted: CIS-MobilePlan-Documents#Online
#
# Sentence: what documents do i need
# Dialogflow: CIS-MobilePlan-Documents, Predicted: CIS-MobilePlan-Documents#Online
#
# Sentence: what documents do i need
# Dialogflow: CIS-MobilePlan-Documents, Predicted: CIS-MobilePlan-Documents#Online
#
# Sentence: what documents do i need
# Dialogflow: CIS-MobilePlan-Documents, Predicted: CIS-MobilePlan-Documents#Online
#
# Sentence: can i convert to cis
# Dialogflow: CIS-MobilePlan-Convert#How, Predicted: CIS-MobilePlan-Convert#CorporateToCIS
#
# Sentence: can i convert to cis
# Dialogflow: CIS-MobilePlan-Convert#How, Predicted: CIS-MobilePlan-Convert#CorporateToCIS
#
# Sentence: what documents do i need
# Dialogflow: CIS-MobilePlan-Documents, Predicted: CIS-MobilePlan-Documents#Online
#
# Sentence: How can I apply for a CIS line?
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-Mobile-AddOn-V019
#
# Sentence: How much is a iPhone?
# Dialogflow: CIS-Devices, Predicted: CIS-Mobile-AddOn-CAST-SportsPlus
#
# Sentence: this is Nhat
# Dialogflow: smalltalk.appraisal.good, Predicted: smalltalk.appraisal.bad
#
# Sentence: blah blah
# Dialogflow: CIS-MobilePlan-EligiblitySingtelCircle, Predicted: smalltalk.emotions.ha_ha
#
# Sentence: blah blah
# Dialogflow: CIS-MobilePlan-EligiblitySingtelCircle, Predicted: smalltalk.emotions.ha_ha
#
# Sentence: Can conversion fees be waived?
# Dialogflow: CIS-Others-FeesWaiver, Predicted: CIS-MobilePlan-RecontractAdminCharges
#
# Sentence: what is cis
# Dialogflow: CIS-About-MenuWhatIsBenefits, Predicted: CIS-HotlineNumber-Service
#
# Sentence: how do i enroll
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: smalltalk.agent.can_you_help
#
# Sentence: How can I apply for a CIS line?
# Dialogflow: CIS-MobilePlan-SignUp, Predicted: CIS-Mobile-AddOn-V019
#
# Accuracy: 0.7481751824817519 - Correct predictions: 410 out of 548
